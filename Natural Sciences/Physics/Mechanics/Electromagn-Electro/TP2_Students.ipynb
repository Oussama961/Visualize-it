# %%
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\D'
# <>:14: SyntaxWarning: invalid escape sequence '\D'
# <>:16: SyntaxWarning: invalid escape sequence '\D'
# <>:13: SyntaxWarning: invalid escape sequence '\D'
# <>:14: SyntaxWarning: invalid escape sequence '\D'
# <>:16: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\oussa\AppData\Local\Temp\ipykernel_4948\1442072235.py:13: SyntaxWarning: invalid escape sequence '\D'
#   plt.plot(DeltaV_f, E_f, '-', label=f"$E={a:.3f}.\Delta V + {b:.3f}$")
# C:\Users\oussa\AppData\Local\Temp\ipykernel_4948\1442072235.py:14: SyntaxWarning: invalid escape sequence '\D'
#   plt.xlabel("$\Delta V (V)$")
# C:\Users\oussa\AppData\Local\Temp\ipykernel_4948\1442072235.py:16: SyntaxWarning: invalid escape sequence '\D'
#   plt.title("Champ electrique $E$ en fonction de la tension $\Delta V$")

# %%
import numpy as np
import matplotlib.pyplot as plt

d = np.array([2.4,5,7.5,10])
E = np.array([3.47,3.65,2.68,2.155])

plt.figure()
plt.plot(d, E, '-', label=f"$E={a:.3f}.\Delta V + {b:.3f}$")
plt.xlabel("distance $d (cm)$")
plt.ylabel("$E (V/cm)$")
plt.title("Champ electrique $E$ en fonction de la distance $d$")
plt.legend()
plt.grid(True)
plt.savefig(".\images\Champ electrique E en fonction de la distance1.png")
plt.show()

plt.figure()
plt.plot(1/d, E, '-', label=f"$E={a:.3f}.\Delta V + {b:.3f}$")
plt.xlabel("distance $1/d (cm)$")
plt.ylabel("$E (V/cm)$")
plt.title("2: Champ electrique $E$ en fonction de la distance $1/d$")
plt.legend()
plt.grid(True)
plt.savefig(".\images\Champ electrique E en fonction de la distance2.png")
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\D'
# <>:14: SyntaxWarning: invalid escape sequence '\i'
# <>:18: SyntaxWarning: invalid escape sequence '\D'
# <>:24: SyntaxWarning: invalid escape sequence '\i'
# <>:8: SyntaxWarning: invalid escape sequence '\D'
# <>:14: SyntaxWarning: invalid escape sequence '\i'
# <>:18: SyntaxWarning: invalid escape sequence '\D'
# <>:24: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\oussa\AppData\Local\Temp\ipykernel_4948\1708184732.py:8: SyntaxWarning: invalid escape sequence '\D'
#   plt.plot(d, E, '-', label=f"$E={a:.3f}.\Delta V + {b:.3f}$")
# C:\Users\oussa\AppData\Local\Temp\ipykernel_4948\1708184732.py:14: SyntaxWarning: invalid escape sequence '\i'
#   plt.savefig(".\images\Champ electrique E en fonction de la distance1.png")
# C:\Users\oussa\AppData\Local\Temp\ipykernel_4948\1708184732.py:18: SyntaxWarning: invalid escape sequence '\D'
#   plt.plot(1/d, E, '-', label=f"$E={a:.3f}.\Delta V + {b:.3f}$")
# ...
