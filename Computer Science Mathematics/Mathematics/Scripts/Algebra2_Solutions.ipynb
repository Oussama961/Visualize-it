# %%
import matplotlib.pyplot as plt
from Modulizing.Vector_spacePlot import plot_vector_addition, plot_scalar_multiplication

# Create a cohesive layout using subplots
# To do: fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot 1: Vector Addition
# To do: plt.sca(ax1)
# plot_vector_addition(u=(1, 2), v=(3, 1), title="Vector Addition (u + v)")
# plt.savefig("../Outputs/Algebra/Vector addition.png")
# Plot 2: Scalar Multiplication
# To do: plt.sca(ax2)
# plot_scalar_multiplication(alpha=2, v=(1, 1), title="Scalar Multiplication (2v)")

# %%
# master_notebook.ipynb
from Modulizing.Vector_spacePlot import plot_vector_addition, plot_scalar_multiplication

# Generate figures
fig1 = plot_vector_addition(u=(1, 2), v=(3, 1))
fig2 = plot_scalar_multiplication(alpha=2, v=(1, 1))

# To do: Save or display

# %%
"""
Propriétés
Si E est un K-e.v, on a les propriétés suivantes :
i/ Va € K, VI Є E, (ax=0
a = 0x ou = 0. ii/ Va e K, V(x, y) E E2, a(x - y) = ax-ay. iii/V(a, B) e K2, Vx e E, (a - ẞ)x = ax - Bx).
1.1.2
Combinaisons linéaires
Définition 1.2.
Soit E un K-e.v et x1,...,xn des vecteurs de E.
i/ On appelle combinaison linéaire des vecteurs 1,, En tout vecteur de la forme Σλιπ; οὐ λ ε K, Vi e {1,..., n}.
i=1
ii/Si A est une partie de E, on appelle combinaison linéaire d'éléments de A toute combinaison linéaire d'un nombre fini d'éléments de A.
Exemples 1.2."""

from Modulizing.Vector_spacePlot import plot_property_i, plot_property_ii, plot_linear_combination

# Example 1: Property (i) - ax = 0 when a=0 or x=0
fig1 = plot_property_i(a=0, x=(2, 3))          # Case 1: a=0
fig2 = plot_property_i(a=2, x=(0, 0))         # Case 2: x=0

# Example 2: Property (ii) - a(x - y) = ax - ay
fig3 = plot_property_ii(a=2, x=(3, 1), y=(1, 2))

# Example 3: Linear combination of vectors
vectors = [(1, 2), (3, 1)]
coefficients = [2, -1]
fig4 = plot_linear_combination(vectors, coefficients)
# Out:
# Error in callback <function _draw_all_if_interactive at 0x000002328F6C1620> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\oussa\anaconda3\envs\bibenv\Lib\site-packages\matplotlib\pyplot.py:279, in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#
# File c:\Users\oussa\anaconda3\envs\bibenv\Lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File c:\Users\oussa\anaconda3\envs\bibenv\Lib\site-packages\matplotlib\backend_bases.py:1891, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
# ...

# %%
"""Property (i):
    Demonstrates that scaling a vector by 0 or scaling the zero vector results in the zero vector.
    Example: plot_property_i(a=0, x=(2, 3)) shows a red zero vector.
Property (ii):
    Compares a(x - y) (blue) with ax - ay (red dashed). They overlap perfectly if the property holds.
Linear Combinations:
    Shows how vectors are scaled and summed (e.g., 2*(1,2) + (-1)*(3,1) = (-1, 3)).
"""
from Modulizing.Vector_Spaces___Product_Spaces import plot_vector_addition_product, plot_scalar_multiplication_product

# Example 1: Addition in E1 × E2
fig1 = plot_vector_addition_product(v1=(2, 3), v2=(1, -1))
# Example 2: Scalar multiplication in E1 × E2
fig2 = plot_scalar_multiplication_product(alpha=2, v=(1.5, -2))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 9
#       1 """Property (i):
#       2     Demonstrates that scaling a vector by 0 or scaling the zero vector results in the zero vector.
#       3     Example: plot_property_i(a=0, x=(2, 3)) shows a red zero vector.
#    (...)      7     Shows how vectors are scaled and summed (e.g., 2*(1,2) + (-1)*(3,1) = (-1, 3)).
#       8 """
# ----> 9 from Modulizing.Vector_Spaces___Product_Spaces import plot_vector_addition_product, plot_scalar_multiplication_product
#      11 # Example 1: Addition in E1 × E2
#      12 fig1 = plot_vector_addition_product(v1=(2, 3), v2=(1, -1))
#
# ImportError: cannot import name 'plot_vector_addition_product' from 'Modulizing.Vector_Spaces___Product_Spaces' (c:\Users\oussa\Documents\Visualize-it\Computer Science Mathematics\Mathematics\Scripts\Modulizing\Vector_Spaces___Product_Spaces.py)

# %%
"""1.1.4 Sous espaces vectoriels
Dans cette partie (E, +,.) représente un K-e.v.
Définition 1.3.
Un sous ensemble F de E est dit sous espace vectoriel de E s'il vérifie les deux conditions suivantes :

i/F# 0,
ii/(F,+,.) est un K-e.v.
Théorème 1.1.
Soit F une partie de E.
Fest un s.e.v de E
{
OE € F,
V(a, b) E K2, V(x, y) E F2, ax+ By F.
Démonstration.
Remarques 1.1.
i/ On peut remplaçer l'hypothèse Op E F par F0.
ii/Un sous espace vectoriel de E est une partie non vide et stable par com-
binaisons linéaires.
Exemples 1.3.

continue for this:"""

from Modulizing.Vector_spacePlot import plot_subspace_example, plot_non_subspace_example

# Example 1: Valid subspace (closed under combinations)
fig1 = plot_subspace_example(
    vectors=[(1, 2), (2, 4)],  # Vectors on the line y = 2x
    title="Subspace: Closed Under Combinations"
)

# Example 2: Invalid subspace (no zero vector, not closed)
fig2 = plot_non_subspace_example(
    vectors=[(1, 3), (2, 5)],  # Vectors on the line y = 2x + 1
    title="Non-Subspace: Violates Closure"
)

# %%
from Modulizing.Vector_spacePlot import (
    plot_intersection_subspaces,
    plot_union_not_subspace,
    plot_span_A
)

# Example 1: Intersection of subspaces (only the origin)
fig1 = plot_intersection_subspaces(subspace1=lambda x: 2*x, subspace2=lambda x: -x)
# Example 2: Union of subspaces is not a subspace
fig2 = plot_union_not_subspace(subspace1=lambda x: 0*x,  # x-axissubspace2=lambda x: x*0   # y-axis)
# Example 3: Span of a subset A = {(1, 1), (2, -1)}
fig3 = plot_span_A(vectors=[(1, 1), (2, -1)])

# %%
"""
1.2.2 Cas d'une partie finie
Proposition 1.3.
Soient nЄ N et A
=
(a1,..., an} une partie finie à n éléments d'un K-e.v
E. Le s.e.v engendré par A est l'ensemble des combinaisons linéaires des
vecteurs a1,..., an
Vect(A)={\/MEK, ie {1,..,n}
Démonstration."""

from vector_spaces.finite_span import plot_finite_span
# Example 1: Span of a single vector (1D subspace)
fig1 = plot_finite_span(vectors=[(2, 1)], title="Vect(A) for A = {a₁} (1D)")
# Example 2: Span of two non-colinear vectors (2D subspace)
fig2 = plot_finite_span(vectors=[(1, 2), (-1, 1)], title="Vect(A) for A = {a₁, a₂} (2D)")

# %%
"""
1.3 Sous espaces vectoriels supplémentaires
et bases d'un e.v
1.3.1 Sous espaces vectoriels supplémentaires
Définition 1.4.
Soient F1,..., F n s.e.v d'un K-e.v E.
L'ensemble F
71
=
{x1+...+n/x, EF, ie {1,.., n}} est un s.e.v de E,
appelé somme des s.e.v F, et noté F F +...+Fn.
Exercice.
Vérifier que F = F1+...+F est un s.e.v de E.
Exemple 1.1.
Remarque 1.2.
F = F1+ +Fn est le s.e.v engendré par FU... UF.
...."""

from Modulizing.Vector_spacePlot import plot_subspace_sum_2d, plot_subspace_sum_3d

# Example 1: 2D Sum of Two Lines (F₁ + F₂)
fig1 = plot_subspace_sum_2d(
    subspaces=[(2, 0), (-0.5, 0)],  # Lines y = 2x and y = -0.5x
    title="Sum of Subspaces in 2D: F₁ + F₂ = ℝ²")

# Example 2: 3D Sum of Two Planes (F₁ + F₂ = ℝ³)
fig2 = plot_subspace_sum_3d(
    subspace1="z=0", 
    subspace2="x=0",
    title="Sum of Subspaces in 3D: F₁ + F₂ = ℝ³")

# %%
"""Définition 1.5.
Soit (E)sign une famille de s.e.v d'un K-e.v E.
12
E s'é
On dit que E, est somme direct des Ei, si tout élément x de E, s'écrit
i=1
Στι
i=1
d'une manière unique sous la forme xxi, avec x, E E;.
n
On écrit E = E1... En.
i=1
i=1


Théorème 1.3.
Soit (Ensign une famille de s.e.v d'un K-e.v E. Sont équivalentes i/ E E ... En,
ii/EnE,
J-1
Démonstration.
Corollaire 1.1.
(0), Vi e {1,...,n) et E-E1+...+En.
Soient F et G deux s.e.v d'un K-e.v E. On a :
E-FOG
FOG= {0} et EF+G.
On dit que F et G sont des s.e.v supplémentaires de E.
Démonstration.
Exemple 1.2.

"""
from Modulizing.Vector_spacePlot import plot_direct_sum_2d, plot_direct_sum_3d

# Example 1: 2D supplementary subspaces (x-axis ⊕ y-axis = ℝ²)
fig1 = plot_direct_sum_2d(subspace1=lambda x: 0*x,  # x-axis (y=0)
    subspace2=lambda x: x*0,   # y-axis (x=0)
    title="E = F ⊕ G (2D)")
# Example 2: 3D supplementary subspaces (plane ⊕ line = ℝ³)
fig2 = plot_direct_sum_3d()

# %%
"""1.3.2 Familles génératrices, Familles libres, Bases
Définition 1.6.
Soient 1,..., n n éléments d'un K-e.v E.
La famille {1,...,xn) est dite génératrice de E si E Vect (x1,...,xn) c-à-d
Remarques 1.2.
Va E E, 3(A1, An) € K", x =
Σλιπ
111
i/Si AC E, alors A est génératrice de E si Vect(A) = E.
ii/ S'il existe dans E une famille génératrice de E finie, on dit que E est de dimension finie. Dans le cas contraire on dit que E est de dimension infinie.
Exemple 1.3.
Définition 1.7.
Soit (i)sign une famille finie d'éléments d'un K-e.v E.

On dit que (xi)sign est une famille libre ou les vecteurs 1,...,: indépendants, si pour toute (A)sign € K", on a :
ΣA11=0=>λ1 = λ2=....=λ = 0.
i=1
In
sont linéairement
Dans le cas contraire, on dit que les vecteurs 1,..., In sont linéairement dépendants ou liés.
Exemple 1.4.
Corollaire 1.2.
Soit (i)isisn une famille libre. Alors:
Démonstration.
Az, = 2,➡A, = 14, Vi € (1.,.,n).
λ=
(1
ᄆ
Définition 1.8. Une famille (e), d'éléments d'un K-e.v E est une base de E, si et seulement si, c'est une famille génératrice et libre de E.

Théorème 1.4.
Une famille (e)sign d'éléments d'un K-e.v E de dimension finie est une base de E, si et seulement si, pour tout vecteur E E il existe une unique famille (A)sign E K" telle quere.
Έλε
1=1
La famille (A)sign est appelée coordonnées (ou composantes) de z dans la
base (e)sisn
Démonstration.
ᄆ
Définition 1.9. Soit E un K-e.v de dimension finie. Toutes les bases de E ont le même nombre d'éléments, on l'appelle dimension de E dans K, et on le note dimxE.
Exemples 1.6.

Remarques 1.3.
Soit E un K-e.v de dimension finie (dimxE = n).
i/Toute famille génératrice de E de n éléments est une base de E. ii/Toute famille libre de E de n éléments est une base de E.
Convetion. On convient que la base de {0} est l'ensemble vide.
Théorème 1.5. (Théorème de la base incomplète)
Si E est un K-e.v non réduit à {0} de dimension finie, et si L est une partie libre de E, alors il existe une base B de E telle que LC B.
Démonstration.
Exemples 1.7.

tel's me how to split this part of the course, if I'll visualise it."""


from Modulizing.Vector_spacePlot import plot_generating_family_2d, plot_linear_independence, plot_basis_3d, plot_incomplete_basis

# Render all visuals in a grid
fig = plt.figure(figsize=(15, 10))
# Generating family example
plt.subplot(2, 2, 1)
plot_generating_family_2d((1, 2), (3, 1))
# Linear independence example
plt.subplot(2, 2, 2)
plot_linear_independence((1, 2), (2, 4))
# Basis and dimension example
plt.subplot(2, 2, 3, projection='3d')
plot_basis_3d((1,0,0), (0,1,0), (0,0,1))
# Incomplete basis theorem
plt.subplot(2, 2, 4)
plot_incomplete_basis()
plt.tight_layout()

# %%
"""1.4 Espaces affines
1.4.1 Définitions et propriétés
Définition 1.10.
Un ensemble non vide & est appelé espace affine de direction E s'il existe une application de x dans E telle que :
i/p(A, B)+(B, C) = (A, C), VA, B, C E §. ii/Pour tout O de & et pour tout vecteur
M tel que l'application (O, M) = .
de E, il existe un unique point
On dit que E est l'espace vectoriel directeur de §.
Les éléments de & sont appelés des points, et ceux de E des vecteurs.
Si E est de dimension finie, on dit que έ est de dimension finie. En général, on appelle dimension de l'espace affine & la dimension de E.
Exemples 1.8.
Remarque 1.3.
Tout R-espace vectoriel est muni d'une structure d'espace affine associé à lui même. Dans ce cas, on confond la notion de point et la notion de vecteur.

Notation
Soient un espace affine de direction E et deux points A et B de . L'unique vecteur associé au bipoint (A, B) est noté AB. Avec cette notation et d'après la définition 1.1 on a AB + BC= AC (relation de Chasles).
Conséquences
Soient un espace affine de direction E et A, B et C trois points de §.
i/ Si A est un point de et un vecteur de E, alors il existe un unique point de & tel que AB = u  et on note B =A + u.
i/ AA = O.
iii/AB=O = A = B. 
iii/ BA = -AB.
Définition 1.11. (Translation)
Soit & un espace affine de direction E. Pour chaque e E, l'application:
est appelée la translation de vecteur, et on la note t

the samement que pour les vecteurs."""
from Modulizing.Vector_spacePlot import plot_affine_space
from Modulizing.axioms_exemples import update_translation

# Example 1: Chasles Relation
points = {'A': (1, 1), 'B': (3, 4), 'C': (4, 6)}
vectors = {('A', 'B'): 'AB', ('B', 'C'): 'BC', ('A', 'C'): 'AC'}
plot_affine_space(points, vectors)

# Example 2: Interactive Translation
update_translation()

# %%
"""1.4.2
Repères d'un espace affine de dimension finie
On a déjà remarqué que le choix d'une origine O permet d'identifier un espace affine & de dimension n à sa direction E, c'est-à-dire à un espace (e1,..., en) de E permet d'identifier cet vectoriel. Le choix d'une base B = espace vectoriel à R".
Le couple R = (0, B) = (0, e1,..., en) est appelé repère cartésien (affine) de §. Pour tout point M de έ, il existe alors un unique n-uplet (x1,...,xn) de réels vérifiant OM = a;e;, Erie, ces nombres sont appelés coordonnées cartésiennes de M dans le repère R.
Exemples 1.10.
i/ Géométrie dans le plan R2. 
ii/Géométrie dans l'espace R3."""

from Modulizing.Vector_spacePlot import update_frame_2d, update_frame_3d
# Example 1: 2D Affine Frame
update_frame_2d()
# Example 2: 3D Affine Frame
update_frame_3d()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 9
#       1 """1.4.2
#       2 Repères d'un espace affine de dimension finie
#       3 On a déjà remarqué que le choix d'une origine O permet d'identifier un espace affine & de dimension n à sa direction E, c'est-à-dire à un espace (e1,..., en) de E permet d'identifier cet vectoriel. Le choix d'une base B = espace vectoriel à R".
#    (...)      6 i/ Géométrie dans le plan R2.
#       7 ii/Géométrie dans l'espace R3."""
# ----> 9 from Modulizing.Vector_spacePlot import update_frame_2d
#      10 from Modulizing.Vector_spacePlot import update_frame_3d
#      11 # Example 1: 2D Affine Frame
#
# ImportError: cannot import name 'update_frame_2d' from 'Modulizing.Vector_spacePlot' (c:\Users\oussa\Documents\Visualize-it\Computer Science Mathematics\Mathematics\Scripts\Modulizing\Vector_spacePlot.py)

# %%
from Modulizing.Vector_spacePlot import plot_affine_subspace, plot_hyperplane_2d, plot_hyperplane_3d, plot_intersection, update_parallel
# Example 1: Affine Subspace
plot_affine_subspace(A=(1, 1), direction_vector=(2, 1))
# Example 2: Hyperplanes
plot_hyperplane_2d(A=(1, 1), normal_vector=(2, 1))
plot_hyperplane_3d(A=(1, 1, 1), normal_vector=(1, 2, 3))
# Example 3: Intersection
plot_intersection(A1=(1, 1), F1=(2, 1), A2=(3, 3), F2=(-1, 1))
# Example 4: Parallel Subspaces (Interactive)
update_parallel()

# %%
"""1.4.4 Barycentres
La notion de barycentre est essentielle en géométrie affine, elle joue le même rôle que celui de la notion de combinaison linéaire dans l'algèbre
linéaire.
Définition 1.15.
Un système de points pondérés d'un espace affine & est une famille finie (Ai, i)in où A, est un élément de E et λ, est un réel, pour tout i. Le poids total du système est le réel.

A tout système de points pondérés de C, on associe une fonction vectorielle de Leibniz du système :
Proposition 1.9.
ƒ(M) = 1⁄2\‚MÅ.
i=1
i/Si le poids total du système est nul, la fonction vectorielle de Leibniz est
constante.
ii/Si le poids total du système n'est pas nul, la fonction vectorielle de Leibniz est une bijection de & sur E. En particulier, il existe un point et un seul où cette fonction s'annule.
Démonstration.
Définition 1.16.
Soit (Ai, i)im, un système de points pondérés d'un espace affine & tel que Σ0. On appelle barycentre de ce système l'unique point G de & vérifiant

Exemples 1.14.
Remarque 1.6.
Le barycentre d'un système de points pondérés n'est défini que si le poids total n'est pas nul.
Propriétés
i/ Le barycentre ne dépend pas de l'ordre des points.
ii/ Homogénéité: le barycentre d'un système de points pondérés ne change pas lorsque l'on multiplie tous les poids par un même réel non nul.
iii/ Associativité : le barycentre d'un système de points pondérés ne change pas lorsqu'on remplace certains de ces points par leur barycentre affecté de la somme des coefficients correspondants.
iv/ Si G est le barycentre de (Ai, Ai)=1,..., alors pour tout O de Є on a :
OG =
Σλί
i=1
Définition 1.17.
On appelle isobarycentre ou centre de gravité d'une famille finie A1,..., An de points de le barycentre de cette famille affecté de poids tous égaux.
Exemples 1.15.

Can you read this? and work on it with the same way"""

from Modulizing.barycenter_plots import plot_barycenter
from Modulizing.interactive_examples import interactive_barycenter, interactive_leibniz
# Example 1: Static barycenter
plot_barycenter(points=[(1, 2), (-1, 3), (2, -1)],weights=[2, 1, -0.5])
# Example 2: Interactive barycenter
interactive_barycenter()
# Example 3: Leibniz vector vanishing at G
interactive_leibniz()

# %% [markdown]
# ### Chapter 2
